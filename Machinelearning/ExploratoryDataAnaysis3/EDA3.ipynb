# %% [markdown]
#                   EXPLORATORY DAYA ANALYSIS 3
# Name - Devanand Saysing Vasave PRN - 1930331245065

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
df = pd.read_csv('C:\\Users\\Devesh\\PycharmProjects\\ProjectA\D001\\train-200907-141856.csv')
# %config InlineBackend.figure_format = 'retina'

# %%
sns.countplot(x='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived',data=df,hue='Sex')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.lineplot(x='Age',y='Fare',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
df.plot.scatter(x='Age',y='Fare')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
df.plot.scatter(x='Age',y='Survived')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Survived'>

# %%
df['Age'].hist(bins=70)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
sizes= df['Survived'].value_counts()
fig1,ax1 = plt.subplots()
ax1.pie(sizes,labels=['Not Survived',
'Survived'],autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# SIMPLE LINEAR REGRESSION
# Name - Devanand Saysing Vasave
# PRN - 1930331245065

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
import math


df = pd.read_csv('C:\\Users\\Devesh\\PycharmProjects\\ProjectA\D001\\amsPredictionSheet1-201009-150447.csv')
df.head()
df.describe()
# Out:
#        Attendance        MSE        HRS        ESE
# count   73.000000  73.000000  73.000000  73.000000
# mean    81.698630   9.780822  12.904110  46.630137
# std      9.506847   3.047069   5.701278   6.617542
# min     62.000000   3.000000   2.000000  32.000000
# 25%     75.000000   8.000000   8.000000  42.000000
# 50%     80.000000  10.000000  14.000000  47.000000
# 75%     90.000000  11.000000  18.000000  50.000000
# max     98.000000  17.000000  22.000000  64.000000

# %%
corr=df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_e26c2_row0_col0, #T_e26c2_row1_col1, #T_e26c2_row2_col2, #T_e26c2_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e26c2_row0_col1, #T_e26c2_row0_col2, #T_e26c2_row0_col3, #T_e26c2_row2_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e26c2_row1_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_e26c2_row1_col2 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_e26c2_row1_col3 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_e26c2_row2_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_e26c2_row2_col3 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_e26c2_row3_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_e26c2_row3_col1 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_e26c2_row3_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# </style>
# <table id="T_e26c2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Attendance</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >HRS</th>
#       <th class="col_heading level0 col3" >ESE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e26c2_level0_row0" class="row_heading level0 row0" >Attendance</th>
#       <td id="T_e26c2_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e26c2_row0_col1" class="data row0 col1" >-0.080943</td>
#       <td id="T_e26c2_row0_col2" class="data row0 col2" >-0.165307</td>
#       <td id="T_e26c2_row0_col3" class="data row0 col3" >-0.109972</td>
#     </tr>
#     <tr>
#       <th id="T_e26c2_level0_row1" class="row_heading level0 row1" >MSE</th>
#       <td id="T_e26c2_row1_col0" class="data row1 col0" >-0.080943</td>
#       <td id="T_e26c2_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e26c2_row1_col2" class="data row1 col2" >0.177060</td>
#       <td id="T_e26c2_row1_col3" class="data row1 col3" >0.751530</td>
#     </tr>
#     <tr>
#       <th id="T_e26c2_level0_row2" class="row_heading level0 row2" >HRS</th>
#       <td id="T_e26c2_row2_col0" class="data row2 col0" >-0.165307</td>
#       <td id="T_e26c2_row2_col1" class="data row2 col1" >0.177060</td>
#       <td id="T_e26c2_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_e26c2_row2_col3" class="data row2 col3" >0.255632</td>
#     </tr>
#     <tr>
#       <th id="T_e26c2_level0_row3" class="row_heading level0 row3" >ESE</th>
#       <td id="T_e26c2_row3_col0" class="data row3 col0" >-0.109972</td>
#       <td id="T_e26c2_row3_col1" class="data row3 col1" >0.751530</td>
#       <td id="T_e26c2_row3_col2" class="data row3 col2" >0.255632</td>
#       <td id="T_e26c2_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
X = df["MSE"]
y = df["ESE"]
sns.scatterplot(X ,y)
# Out:
# <AxesSubplot:xlabel='MSE', ylabel='ESE'>

# %%
endog = df['ESE']
exog = sm.add_constant(df[['MSE']])
print(exog)
# Out:
#     const  MSE
# 0     1.0   10
# 1     1.0    7
# 2     1.0    3
# 3     1.0   16
# 4     1.0    9
# ..    ...  ...
# 68    1.0   10
# 69    1.0    8
# 70    1.0    9
# 71    1.0   11
# 72    1.0   12
#
# [73 rows x 2 columns]

# %%
mod = sm.OLS(endog, exog)
results = mod.fit()
print (results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ESE   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.559
# Method:                 Least Squares   F-statistic:                     92.14
# Date:                Sun, 26 Dec 2021   Prob (F-statistic):           1.85e-14
# Time:                        14:16:16   Log-Likelihood:                -210.66
# No. Observations:                  73   AIC:                             425.3
# Df Residuals:                      71   BIC:                             429.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         30.6664      1.741     17.616      0.000      27.195      34.137
# MSE            1.6322      0.170      9.599      0.000       1.293       1.971
# ==============================================================================
# Omnibus:                        1.412   Durbin-Watson:                   1.441
# Prob(Omnibus):                  0.494   Jarque-Bera (JB):                1.119
# Skew:                          -0.029   Prob(JB):                        0.572
# Kurtosis:                       2.396   Cond. No.                         34.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
def RSE(y_true, y_predicted):
   
    y_true = np.array(y_true)
    y_predicted = np.array(y_predicted)
    RSS = np.sum(np.square(y_true - y_predicted))

    rse = math.sqrt(RSS / (len(y_true) - 2))
    return rse

# %%
rse= RSE(df['ESE'],results.predict())
print(rse)
# Out:
# 4.396224549647787

# %%
X1 = df["Attendance"]
y1 = df["ESE"]

sns.scatterplot(X1 ,y1)
# Out:
# <AxesSubplot:xlabel='Attendance', ylabel='ESE'>

# %%
endog1 = df['ESE']
exog1 = sm.add_constant(df[['Attendance']])
print(exog)
# Out:
#     const  MSE
# 0     1.0   10
# 1     1.0    7
# 2     1.0    3
# 3     1.0   16
# 4     1.0    9
# ..    ...  ...
# 68    1.0   10
# 69    1.0    8
# 70    1.0    9
# 71    1.0   11
# 72    1.0   12
#
# [73 rows x 2 columns]

# %%
mod1 = sm.OLS(endog1, exog1)
results1 = mod1.fit()
print (results1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    ESE   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.8692
# Date:                Sun, 26 Dec 2021   Prob (F-statistic):              0.354
# Time:                        14:16:28   Log-Likelihood:                -240.58
# No. Observations:                  73   AIC:                             485.2
# Df Residuals:                      71   BIC:                             489.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         52.8841      6.753      7.831      0.000      39.419      66.349
# Attendance    -0.0765      0.082     -0.932      0.354      -0.240       0.087
# ==============================================================================
# Omnibus:                        0.286   Durbin-Watson:                   1.788
# Prob(Omnibus):                  0.867   Jarque-Bera (JB):                0.425
# Skew:                           0.129   Prob(JB):                        0.808
# Kurtosis:                       2.730   Cond. No.                         716.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
